# %%
#tipos diferentes de conectores

# mysqlconnector - pip install mysql-connector-python
# pymysql - pip install pymysql
# mysqldb - pip install MySQL-python ou pip install mysqlclient

# %%
from sqlalchemy import create_engine

#conexao ( Com erro para teste)

eng = create_engine("mysql+pymysql://root12345@localhost/python")

conn = eng.connect()

query = """ 
    SELECT 
        `c`.`name` AS `category`, SUM(`p`.`amount`) AS `total_sales`
    FROM
        (((((`sakila`.`payment` `p`
        JOIN `sakila`.`rental` `r` ON ((`p`.`rental_id` = `r`.`rental_id`)))
        JOIN `sakila`.`inventory` `i` ON ((`r`.`inventory_id` = `i`.`inventory_id`)))
        JOIN `sakila`.`film` `f` ON ((`i`.`film_id` = `f`.`film_id`)))
        JOIN `sakila`.`film_category` `fc` ON ((`f`.`film_id` = `fc`.`film_id`)))
        JOIN `sakila`.`category` `c` ON ((`fc`.`category_id` = `c`.`category_id`)))
    GROUP BY `c`.`name`
    ORDER BY `total_sales` DESC
"""

resultado = conn.execute(query)

# ver linhas
for row in resultado:
  print(row)

conn.close()
eng.dispose # libera todos os recursos associados ao objeto eng (mecanismo SQLAlchemy) incluindo todas conexão abertar
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\curso-eng-dados\Python-SGBDS\sgbds\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\curso-eng-dados\Python-SGBDS\sgbds\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)   3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File c:\curso-eng-dados\Python-SGBDS\sgbds\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
# ...

# %% [markdown]
# Resolvendo erro : SQLAlchemy não sabe como executar diretamente essa string remove colocando query entre ()

# %%
from sqlalchemy import create_engine,text

eng = create_engine("mysql+pymysql://root:12345@localhost/python")
cursor = eng.connect()

query = text(""" 
    SELECT 
        `c`.`name` AS `category`, SUM(`p`.`amount`) AS `total_sales`
    FROM
        (((((`sakila`.`payment` `p`
        JOIN `sakila`.`rental` `r` ON ((`p`.`rental_id` = `r`.`rental_id`)))
        JOIN `sakila`.`inventory` `i` ON ((`r`.`inventory_id` = `i`.`inventory_id`)))
        JOIN `sakila`.`film` `f` ON ((`i`.`film_id` = `f`.`film_id`)))
        JOIN `sakila`.`film_category` `fc` ON ((`f`.`film_id` = `fc`.`film_id`)))
        JOIN `sakila`.`category` `c` ON ((`fc`.`category_id` = `c`.`category_id`)))
    GROUP BY `c`.`name`
    ORDER BY `total_sales` DESC
""")

resultado = conn.execute(query)

for row in resultado:
  print(row)

cursor.close()
eng.dispose()
# Out:
# ('Sports', Decimal('5314.21'))
# ('Sci-Fi', Decimal('4756.98'))
# ('Animation', Decimal('4656.30'))
# ('Drama', Decimal('4587.39'))
# ('Comedy', Decimal('4383.58'))
# ('Action', Decimal('4375.85'))
# ('New', Decimal('4351.62'))
# ('Games', Decimal('4281.33'))
# ('Foreign', Decimal('4270.67'))
# ('Family', Decimal('4226.07'))
# ('Documentary', Decimal('4217.52'))
# ('Horror', Decimal('3722.54'))
# ('Children', Decimal('3655.55'))
# ('Classics', Decimal('3639.59'))
# ('Travel', Decimal('3549.64'))
# ('Music', Decimal('3417.72'))

# %% [markdown]
# Transformando em DataFrame

# %%
from sqlalchemy import create_engine,text
import pandas as pd

eng = create_engine("mysql+pymysql://root:12345@localhost/python")

conn = eng.connect()

query = text(""" 
    SELECT * FROM python.customers
""")

df_clientes = pd.read_sql(query,eng)

conn.close()
eng.dispose()
df_clientes.head()
# Out:
#     category  total_sales
# 0     Sports      5314.21
# 1     Sci-Fi      4756.98
# 2  Animation      4656.30
# 3      Drama      4587.39
# 4     Comedy      4383.58

# %%
#tipos diferentes de conectores

# mysqlconnector - pip install mysql-connector-python
# pymysql - pip install pymysql
# mysqldb - pip install MySQL-python ou pip install mysqlclient

# %%
from sqlalchemy import create_engine,text
import pandas as pd

eng = create_engine("mysql+mysqldb://root:12345@localhost/python")

conn = eng.connect()

query = text(""" 
    SELECT * FROM python.customers
""")

df_clientes = pd.read_sql(query,eng)

conn.close()
eng.dispose()
df_clientes.head()
# Out:
#    customer_id  first_name last_name           phone                    email  \
# 0            1       Debra     Burks                    debra.burks@yahoo.com
# 1            2       Kasha      Todd                     kasha.todd@yahoo.com
# 2            3      Tameka    Fisher                    tameka.fisher@aol.com
# 3            4       Daryl    Spence                     daryl.spence@aol.com
# 4            5  Charolette      Rice  (916) 381-6003  charolette.rice@msn.com
#
#                   street           city state  zip_code
# 0      9273 Thorne Ave.    Orchard Park    NY     14127
# 1       910 Vine Street        Campbell    CA     95008
# 2  769C Honey Creek St.   Redondo Beach    CA     90278
# 3        988 Pearl Lane       Uniondale    NY     11553
# 4         107 River Dr.      Sacramento    CA     95820
