# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# %%
# especifique as credencias
credencial = {
  "type": "service_account",
  "project_id": "pythoncurso-462414",
  "private_key_id": "f5463d5035abe6da397ecb3eda8e1136c6941960",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "aulapythoncurso@pythoncurso-462414.iam.gserviceaccount.com",
  "client_id": "104107766289318072192",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/aulapythoncurso%40pythoncurso-462414.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}

# Crie o cliente BigQuery
client = bigquery.Client(credentials=service_account.Credentials.from_service_account_info(credencial))

# %%
#Construa sua consulta
query = """
SELECT 
  id
  ,first_name
  ,last_name
  ,email
FROM `pythoncurso-462414.AulaPython.Clientes`
where state in('Sao Paulo','Santa Catarina')
"""
#Execute a consulta
resultado = client.query(query)

# Converta os resultados em um Data frame
df = resultado.to_dataframe()
df.head()
